# %% [markdown]
# # Get Dataset

# %%
# %pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="thereisnoapikey")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# Requirement already satisfied: roboflow in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (1.4.1)
# Requirement already satisfied: certifi in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (2026.7.22)
# Requirement already satisfied: idna>=3.7 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (3.19)
# Requirement already satisfied: cycler in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (1.5.1)
# Requirement already satisfied: matplotlib in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (3.11.1)
# Requirement already satisfied: numpy<2.4,>=1.18.5 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (2.3.5)
# Requirement already satisfied: opencv-python-headless>=4.10.0 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (5.0.0.93)
# Requirement already satisfied: Pillow>=7.1.2 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (12.3.0)
# Requirement already satisfied: pi-heif<2 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (1.4.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (1.6.0)
# Requirement already satisfied: python-dateutil in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (1.2.3)
# Requirement already satisfied: requests in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (2.34.2)
# Requirement already satisfied: six in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (2.7.0)
# Requirement already satisfied: tqdm>=4.41.0 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (4.70.0)
# Requirement already satisfied: PyYAML>=5.3.1 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (6.0.3)
# Requirement already satisfied: requests_toolbelt in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (1.2.0)
# Requirement already satisfied: typer<0.26,>=0.12.0 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (0.25.1)
# Requirement already satisfied: click>=8.0 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from roboflow) (8.5.0)
# Requirement already satisfied: shellingham>=1.3.0 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from typer<0.26,>=0.12.0->roboflow) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from typer<0.26,>=0.12.0->roboflow) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from typer<0.26,>=0.12.0->roboflow) (0.0.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (2.21.0)
# Requirement already satisfied: mdurl~=0.1 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26,>=0.12.0->roboflow) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.28.2 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from matplotlib->roboflow) (4.64.0)
# Requirement already satisfied: packaging>=20.0 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from matplotlib->roboflow) (26.3)
# Requirement already satisfied: pyparsing>=3 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from matplotlib->roboflow) (3.3.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/ph3onix/Downloads/projects/final_project/football_env/lib/python3.14/site-packages (from requests->roboflow) (3.5.1)
# Note: you may need to restart the kernel to use updated packages.
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# '/home/ph3onix/Downloads/projects/final_project/training/football-players-detection-1'

# %% [markdown]
# # Training

# %%
# %yolo task=detect mode=train model='yolov5m.pt' data={dataset.location}/data.yaml epochs=100 imgsz=640
